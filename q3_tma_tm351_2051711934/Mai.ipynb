# %% [markdown]
# # *Q3:Mai Gamal salah Tm351 with id:2051711934*

# %%
import pandas as pd ##impot dataFtrame library
data_frame=pd.read_csv(r"C:\Users\sun com\Downloads\2015.csv")#read in 2015 csv file
data_frame ##print the data set
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# counrty by name
data_frame[data_frame['Country'] == 'South Africa']
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 112  South Africa  Sub-Saharan Africa             113            4.642
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 112         0.04585                   0.92049  1.18468
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 112                   0.27688  0.33207                        0.08884
#
#      Generosity  Dystopia Residual
# 112     0.11973            1.71956

# %%
#display top 10  by Happiness Rank
data_frame.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
data_frame.describe() #different for each column and including mean, count.
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
data_frame.isnull().sum() ## to get the total of null to known if it dirtness or no
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data_frame.info()#Dataframe information contain 158 countries, 12 columns with no missing records,
##and the data type of all column.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
##display bottom 10 countries by Happiness Rank
data_frame.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %% [markdown]
# # *Visualizing the data set*

# %%
data_frame['Happiness Score'].groupby(data_frame['Region']).describe()##Happiness score statistics based on region
# Out:
#                                  count      mean       std    min      25%  \
# Region
# Australia and New Zealand          2.0  7.285000  0.001414  7.284  7.28450
# Central and Eastern Europe        29.0  5.332931  0.570446  4.218  4.95900
# Eastern Asia                       6.0  5.626167  0.554053  4.874  5.22350
# Latin America and Caribbean       22.0  6.144682  0.728560  4.518  5.84050
# Middle East and Northern Africa   20.0  5.406900  1.101382  3.006  4.70775
# North America                      2.0  7.273000  0.217789  7.119  7.19600
# Southeastern Asia                  9.0  5.317444  0.950020  3.819  4.87600
# Southern Asia                      7.0  4.580857  0.570526  3.575  4.39250
# Sub-Saharan Africa                40.0  4.202800  0.609557  2.839  3.75600
# Western Europe                    21.0  6.689619  0.824582  4.857  6.30200
#
#                                    50%      75%    max
# Region
# Australia and New Zealand        7.285  7.28550  7.286
# ...

# %%
##Similar data that compares the rankings of countries within each region.
data_frame['Happiness Rank'].groupby(data_frame['Region']).describe()
# Out:
#                                  count        mean        std   min     25%  \
# Region
# Australia and New Zealand          2.0    9.500000   0.707107   9.0    9.25
# Central and Eastern Europe        29.0   79.000000  26.667262  31.0   59.00
# Eastern Asia                       6.0   64.500000  24.688054  38.0   46.25
# Latin America and Caribbean       22.0   46.909091  28.716859  12.0   27.75
# Middle East and Northern Africa   20.0   77.600000  43.213546  11.0   38.00
# North America                      2.0   10.000000   7.071068   5.0    7.50
# Southeastern Asia                  9.0   81.222222  39.917971  24.0   61.00
# Southern Asia                      7.0  113.142857  26.573349  79.0   95.00
# Sub-Saharan Africa                40.0  127.900000  22.863923  71.0  115.75
# Western Europe                    21.0   29.523810  29.268787   1.0    7.00
#
#                                    50%     75%    max
# Region
# Australia and New Zealand          9.5    9.75   10.0
# ...

# %%
Happay = data_frame['Happiness Score'] ##define rate happeniess
economic = data_frame['Economy (GDP per Capita)']##define rate in column Economy (GDP per Capita)

# %%
from scipy.stats import pearsonr    ## imports scipy to calculating the Pearson correlation coefficient between two variables.

correlation, var = pearsonr(Happay, economic)##calculating the Pearson correlation

print('Correlation efficient:', correlation)
print('p-value:', var)
# Out:
# Correlation coefficient: 0.7809655268660216
# p-value: 1.0505384131958323e-33

# %%
    ## define pivot_table
pivotable = pd.pivot_table(data_frame, values='Happiness Score', index='Region',
                             columns='Economy (GDP per Capita)', aggfunc='mean')

    ##define crostable
crostable = pd.crosstab(data_frame['Economy (GDP per Capita)'],pd.cut(data_frame['Happiness Score'], [1, 4, 6, 11]))

print('Pivot table:\n')##print all that
print(pivotable)

print('Crosstab:')
print(crostable)
# Out:
# Pivot table:
#
# Economy (GDP per Capita)         0.00000  0.01530  0.01604  0.06940  0.07120  \
# Region
# Australia and New Zealand            NaN      NaN      NaN      NaN      NaN
# Central and Eastern Europe           NaN      NaN      NaN      NaN      NaN
# Eastern Asia                         NaN      NaN      NaN      NaN      NaN
# Latin America and Caribbean          NaN      NaN      NaN      NaN      NaN
# Middle East and Northern Africa      NaN      NaN      NaN      NaN      NaN
# North America                        NaN      NaN      NaN      NaN      NaN
# Southeastern Asia                    NaN      NaN      NaN      NaN      NaN
# Southern Asia                        NaN      NaN      NaN      NaN      NaN
# Sub-Saharan Africa                 4.517    2.905    4.292    3.845    4.571
# Western Europe                       NaN      NaN      NaN      NaN      NaN
#
# Economy (GDP per Capita)         0.07850  0.08308  0.17417  0.18847  0.19073  \
# Region
# ...

# %%
import seaborn as sae # create a scatter plot
sae.regplot(x=data_frame['Economy (GDP per Capita)'], y=data_frame['Happiness Score'])##A plot depicting a positive correlation,
                                                                        ##where the Happiness Score increases along with an increase in the Economy's GDP per Capita.
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
import matplotlib.pyplot as p  ##creating a variety of plots and charts in Python import library.
##bar chart
joined = data_frame.groupby('Region')['Happiness Score'].mean()
p.bar(joined.index, joined.values)
p.xticks(rotation=90)
p.xlabel('Region')
p.ylabel('Mean Happiness Score')
p.title('Bar Chart of Mean Happiness Score by Region')
p.show()

# %%
##create a box plot of the happiness score and economy
import matplotlib.pyplot as p  ##creating a variety of plots and charts in Python import library.
from scipy.stats import pearsonr    ## imports scipy to calculating the Pearson correlation coefficient between two variables.
sae.boxplot(x='Happiness Score', y='Economy (GDP per Capita)', data=data_frame)
p.xlabel('Happiness Score')
p.ylabel('Economy (GDP per Capita)')
p.title('Box Plot of Happiness Score and Economy')
p.show()

# %%
from scipy.stats import pearsonr    ## imports scipy to calculating the Pearson correlation coefficient between two variables.
relation = data_frame.drop(['Happiness Rank', 'Country', 'Region'], axis=1).corr()
relation
##display correlation matrix
sae.heatmap(relation)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as p  ##creating a variety of plots and charts in Python import library.
from scipy.stats import pearsonr    ## imports scipy to calculating the Pearson correlation coefficient between two variables.
# built heat maps
pivot_table = data_frame.pivot_table(index='Region', columns='Economy (GDP per Capita)',values='Happiness Score', aggfunc='mean')
sae.heatmap(pivot_table, cmap='YlGnBu')
p.xlabel('Economy (GDP per Capita)')
p.ylabel('Region')
p.title('Heatmap of Happiness Score vs. Economy by Region')
p.show()
